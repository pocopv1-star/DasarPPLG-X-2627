# %% [markdown]
# <a href="https://colab.research.google.com/github/pocopv1-star/DasarPPLG-X-2627/blob/main/X_PPLG_Alvino_Setyawan_R_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 praktik 1: membuat variabel

# %% [markdown]
# Tugas 1 Praktik membuat tipe data dan variabel
# Nama Kelompok:Jawa Barat
# Nama Anggota:
# 1. Alliyah Herawati
# 2. Hayun Hasanah
# 3. Alvino Setyawan Ramadhan
# 4. Miftahul Hilmi
# 5. Radit Saputra
# 6. M. Shal Alfaraz

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Laptop Asus";
#     int jumlah = 2;
#     float harga = 7500000.50;
#     char kategori = 'A';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Writing praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Laptop Asus
# Kategori    : A
# Jumlah      : 2
# Harga       : Rp 7.5e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
